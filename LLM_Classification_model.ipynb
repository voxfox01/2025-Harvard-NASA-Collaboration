# %% [markdown]
# <a href="https://colab.research.google.com/github/voxfox01/2025-Harvard-NASA-Collaboration/blob/main/LLM_Classification_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %%
# Need Install libraries
# !pip install s3fs --quiet
# !pip install ctransformers --no-binary ctransformers --quiet
# !pip install -U bitsandbytes --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 MB 29.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 105.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 39.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 90.2 MB/s eta 0:00:00

# %%
# Data Manipulations
import pandas as pd
import numpy as np

# System
import os
import sys
import gc

# Deep learning
import torch

# LLM
#from ctransformers import AutoModelForCausalLM
from transformers import AutoConfig, AutoModelForCausalLM, AutoTokenizer

# Model repositories
from huggingface_hub import notebook_login, login

# AWS
import s3fs

# Colab
from google.colab import userdata

# %% [markdown]
# ## Credentials variables

# %%
# AWS Environment variables
os.environ['AWS_ACCESS_KEY_ID'] = userdata.get('nasa_aws_key')
os.environ['AWS_SECRET_ACCESS_KEY'] = userdata.get('nasa_aws_secret_key')
os.environ['AWS_DEFAULT_REGION'] = 'us-west-2'

# %%
# Saving path
data_path = "/content/drive/MyDrive/Harvard/Capstone/Classification/"

# %% [markdown]
# # Load Data (GlOBE site data)

# %%
globe_site_data = pd.read_csv(data_path + "globe_site_data_20250227.csv", dtype=str, low_memory=False)
globe_site_data.columns = globe_site_data.columns.str.strip()

print(globe_site_data.shape)
globe_site_data.head(3)
# Out:
# (28174, 25)
#   site_id                          name    latitude   longitude elevation  \
# 0       1                 GLOBE Boulder        40.1     -105.17      1655
# 1    1000  Surface Water Site 01:SWS-01      6.4167      2.6667      16.1
# 2  100001                   22JGS446679  -25.586154  -48.564832       8.1
#
#   elevation_type location_source                                     comments  \
# 0            NaN             gps                                          NaN
# 1    ellipsoidal             gps  please replace with Hydrology Site Comments
# 2            NaN             gps                                          NaN
#
#     activated_at             water_body_name  ... area_unit depth depth_unit  \
# 0        13:18.1  Mosquito Source Water Body  ...       NaN   NaN        NaN
# 1  4/4/2004 0:00                         NaN  ...       NaN   NaN        NaN
# 2        24:31.2            Mosquito Habitat  ...       NaN   NaN        NaN
#
#   water_sample_location can_see_bottom bank_material bedrock_type  \
# 0                   NaN            NaN       Unknown      Unknown
# 1                   NaN            NaN       Unknown      Unknown
# 2                   NaN            NaN       Unknown      Unknown
#
#   freshwater_habitat salt_habitat harvard_class
# 0                NaN          NaN         Marsh
# 1                NaN          NaN  River_Stream
# 2                NaN          NaN  River_Stream
#
# [3 rows x 25 columns]

# %%
# S3 data url
s3_url = "s3://hes-dscap-staging/globe_site_data/globe_siteinfo_20250227.csv"
globe_site_data = pd.read_csv(s3_url, dtype=str, low_memory=False)
globe_site_data.columns = globe_site_data.columns.str.strip() # Remove trailing whitespaces from column names

print(globe_site_data.shape)
globe_site_data.head(3)
# Out:
# (28174, 24)
#   site_id                          name    latitude   longitude elevation  \
# 0       1                 GLOBE Boulder        40.1     -105.17    1655.0
# 1    1000  Surface Water Site 01:SWS-01      6.4167      2.6667      16.1
# 2  100001                   22JGS446679  -25.586154  -48.564832       8.1
#
#   elevation_type location_source                                     comments  \
# 0            NaN             gps                                          NaN
# 1    ellipsoidal             gps  please replace with Hydrology Site Comments
# 2            NaN             gps                                          NaN
#
#                  activated_at             water_body_name  ... area area_unit  \
# 0  2018-09-12 23:13:18.149608  Mosquito Source Water Body  ...  NaN       NaN
# 1         2004-04-04 00:00:00                         NaN  ...  NaN       NaN
# 2   2017-10-04 20:24:31.16618            Mosquito Habitat  ...  NaN       NaN
#
#   depth depth_unit water_sample_location can_see_bottom bank_material  \
# 0   NaN        NaN                   NaN            NaN       Unknown
# 1   NaN        NaN                   NaN            NaN       Unknown
# 2   NaN        NaN                   NaN            NaN       Unknown
#
#   bedrock_type freshwater_habitat salt_habitat
# 0      Unknown                NaN          NaN
# 1      Unknown                NaN          NaN
# 2      Unknown                NaN          NaN
#
# [3 rows x 24 columns]

# %%
# S3 data url
s3_url = "s3://hes-dscap-staging/GLOBE_Data/transparencies_1995-03-26_2025-01-11.csv"
globe_df = pd.read_csv(s3_url, dtype=str, low_memory=False)
globe_df.columns = globe_df.columns.str.strip() # Remove trailing whitespaces from column names

print(globe_df.shape)
globe_df.head(3)
# Out:
# (160273, 22)
#   countryCode   countryName elevation organizationId  \
# 0         SAU  Saudi Arabia      27.0        6509520
# 1         SAU  Saudi Arabia      18.0        6509520
# 2         SAU  Saudi Arabia       0.0        6509520
#
#               organizationName        protocol  siteId  \
# 0  Saudi Arabia GLOBE v-School  transparencies  100568
# 1  Saudi Arabia GLOBE v-School  transparencies  369589
# 2  Saudi Arabia GLOBE v-School  transparencies  370172
#
#                              siteName transparenciesComments  \
# 0  Ali Bin Abi Talib Secondary School                    NaN
# 1                   Prince Majed Park                    NaN
# 2                    Salman Bay Beach                    NaN
#
#   transparenciesMeasuredAt  ... transparenciesSensorTurbidityNtu  \
# 0      2025-01-11 09:02:00  ...                              NaN
# 1      2025-01-11 09:02:00  ...                              NaN
# 2      2025-01-11 09:02:00  ...                              NaN
#
#   transparenciesTransparencyDiskDoesNotDisappear  \
# 0                                          false
# 1                                          false
# 2                                          false
#
#   transparenciesTransparencyDiskImageDisappearanceM  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
#
#   transparenciesTubeImageDisappearanceCm  \
# 0                                     60
# 1                                     60
# 2                                     60
#
#   transparenciesTubeImageDoesNotDisappear transparenciesUserid  \
# 0                                   false             13136805
# 1                                   false             13136805
# 2                                   false             13136805
#
#   transparenciesWaterBodyState   latitude  longitude transparenciesGlobeTeams
# 0                       normal  21.577892  39.202318                      NaN
# 1                       normal  21.590226  39.182741                      NaN
# 2                       normal  21.859427  38.978633                      NaN
#
# [3 rows x 22 columns]

# %% [markdown]
# - Example of looking at instance

# %% [markdown]
# # EDA

# %% [markdown]
# ## Current types of water bodies

# %%
globe_site_data.columns
# Out:
# Index(['site_id', 'name', 'latitude', 'longitude', 'elevation',
#        'elevation_type', 'location_source', 'comments', 'activated_at',
#        'water_body_name', 'water_body_type', 'water_body_source',
#        'bank_to_bank_distance', 'bank_to_bank_distance_unit', 'area',
#        'area_unit', 'depth', 'depth_unit', 'water_sample_location',
#        'can_see_bottom', 'bank_material', 'bedrock_type', 'freshwater_habitat',
#        'salt_habitat'],
#       dtype='object')

# %%
globe_site_data.water_body_name.unique().tolist()
# Out:
# ['Mosquito Source Water Body',
#  nan,
#  'Mosquito Habitat',
#  'traps',
#  'river',
#  'KAIKORAI  STREAM',
#  'Marine, Shakespeare Bay',
#  'Middle Patuxent River',
#  'Unnamed stream, tributary to Opihi River',
#  'River mouth',
#  'بئر',
#  'Sandstone Stream',
#  'Sandstone Catchment',
#  'sandstone cachtment',
#  'Waters of Leith',
#  'watres of leith',
#  'waters of leith',
#  'major tributary of the kaikorai stream',
#  'Kaikorai Estuary',
#  'Olšava',
#  'خزان ارضي',
#  'Río Huallaga',
#  'Lake Rotorua',
#  'Lake Okataina',
#  'Hamurana',
#  'lake',
#  'Arroyo Canelón Chico',
#  'Poormans Stream',
#  'Wierzyca',
#  'Próbka',
#  'Poorman Valley Stream',
#  'Waihopai River',
#  'Oreti River (Esuary)',
#  'Otepuni Stream',
#  'Wyndham Wildlife Refuge Pond',
#  'Unnamed Stream tributory  to Mangahou river',
#  'Tomahawk Lagoon, Northern Arm',
#  'Kwethluk River',
#  'gohareya',
#  'Waiaua River',
#  'Unnamed Drainage Ditch',
#  'Otama steam',
#  'Otama Stream',
#  'falaj',
#  'Otama stream',
#  'Taylor River, White Bridge',
#  'Marlborough Sounds, Blumine Is Beach',
#  'Wairau River HW1 Bridge',
#  'Winton Channel',
#  'Manawatu River, Ashhurst Domain',
#  'Ashhurst Domain Native Forest Wetland',
#  'water tank',
#  'Waimairi stream',
#  'ŠUMETLICA',
#  'ŠUMETLICA 2',
#  'Unnamed tributary to the Waikato River ',
#  'Red Sea',
#  'بركة',
#  'Schuylkill river',
#  'Birchville Reservior Stream',
#  'L. Mitchell',
#  'Blue Creek',
#  'bromelia SESC',
#  'Elk River',
#  'Unnamed Stream, Outlet from Wakaaranga Estuary',
#  'Gold Creek',
#  'Little Beech Creek',
#  'GOLD CREAK',
#  'Berek',
#  'Unnamed Pond - no surface inflow or outlfow (this implies a groundwater source)',
#  'Little Sydney Valley stream',
#  'Beaver Creek',
#  'Te Puru Creek',
#  'Firth of Thames',
#  'home tank',
#  'Brooklyn stream 100m above bridge ',
#  'kaituna river\n',
#  'kaituna river',
#  'kaituna 3',
#  'Otomega pond',
#  'Kaupokonui River',
#  'WATER  WHEELS',
#  'Dienvidsuseja',
#  'Little Go',
#  'Alfred Stream',
#  'Te Henui River',
#  'เเม่น้ำจัน',
#  'ลำน้ำท้ายนาข้าว',
#  'ลำน้ำหน้าวัดแม่คี',
#  'Bayou St. John',
#  'Reservoir',
#  'Greenhill Stream',
#  'Sand Creek',
#  'Ngatimoti Stream',
#  '123',
#  'Tank',
#  'Reservoir Creek',
#  'Sausal Creek',
#  'Fonterra Stream',
#  'Headwaters of Whau river',
#  'Glen Eden Stream',
#  'Unnamed stream: Flexmans',
#  'Krapinica river',
#  'Sagarah',
#  'Fleet Stream',
#  'Kuriwao Stream',
#  'หนองบัว',
#  'บ่อเลี้ยงปลาบ้านป่าบง',
#  'Drava',
#  'Water tank',
#  'what tank',
#  'TANK Water',
#  'water ibri',
#  'KMSH Pool',
#  'Rio Changuinola',
#  'Unnamed Pond- Glenmore',
#  'Lake Pontchartrain',
#  'tank water',
#  'RIO RIMAC, ALTURA DEL PUENTE HUAYCOLORO DEL DISTRITO DE HUACHIPA',
#  'rio Rimac',
#  'Wall',
#  'Glenmore Reservour',
#  '十六份排水溝',
#  'فلج',
#  'Rio Palcazu',
#  'مجرى ماء بلا اسم',
#  'distilled water',
#  'RIO RIMAC',
#  'Rimac',
#  'Agua Superficial del rio rimac',
#  'RIO PARANA',
#  'Superficie del Agua del Rio Rimac',
#  'Thorofare Canal, Detroit River',
#  'Detroit River',
#  'Donaldson Run',
#  'Rio Huancabamaba',
#  'Galva Canal',
#  'Pozo',
#  'Rio Pichis',
#  'Quebrada Yanizu ',
#  'Quebrada Yanizu 2',
#  'Lake Lakaram',
#  'อ่างเก็บน้ำห้วยไร่ Huai Rai Reservoir',
#  'Rio Pachitea',
#  'Rio',
#  'Confluyen los desagues',
#  'Rio Pintoyacu',
#  'OL Stream',
#  'Stream',
#  'Champs Pond',
#  'Quebrada Carmen',
#  'Rio Mayro',
#  'RIO',
#  'AGUA',
#  'สระน้ำข้างอาคารเกษตร',
#  'خزان مياه المدرسة',
#  'Quebrada',
#  'สระน้ำข้างโรงรถนักเรียน',
#  'Vrapcak_stream',
#  'Sutinska vrela_stream',
#  'Rio Madre de Dios',
#  'Unnamed Pond',
#  'Science BUU pond',
#  'สระน้ำ',
#  'Science pond',
#  'PSHS Creek',
#  'Pond near department of chemistry, Burapha university',
#  'Pond near department of chemistry, Burapha University',
#  'Science\u200b pond',
#  'Science Pond',
#  'Starvation Cove',
#  'LA MESA DAM',
#  'สระน้ำไม่มีชื่อ- ไม่มีทางน้ำไหลเข้าออก (แสดงว่าเป็นแหล่งน้ำผิวดิน)',
#  'bay',
#  'Manila Bay',
#  'Chem pond',
#  'Chem BUU Pond',
#  'Masao River',
#  'ห้วยไร่ฝาย Huai Rai Dam',
#  'Mabel River',
#  'Inayan Beach',
#  'Chem BUU pond',
#  'Pisay Creek',
#  'Phopaya floating market',
#  'water gate',
#  'pihandang temple',
#  'Tharaburi restaurant',
#  'Royal  forest  SP',
#  'Suphanburi market',
#  'Youth Center SP',
#  'rice paddy field',
#  'thajin',
#  'inorganic rice paddy fleid',
#  'Thajin',
#  'Tariq Road Natural Spring Lake',
#  'Unnamed Pond - no surface inflow or outlfow',
#  "Classroom building1's ditch",
#  'reservoire',
#  'RAWAL LAKE',
#  'CHATTAR STREAM',
#  'SHAHDRA STREAM',
#  'WATER3',
#  'Odra',
#  'Test',
#  'RADUNIA SWS-2',
#  'kanal RADUNIA',
#  'Lateralac',
#  'Lake Superior',
#  'Klodnica',
#  'Slepiotka',
#  'KLODNICA',
#  'KLODNICA RIVER ',
#  'albustan wall',
#  'Daugava',
#  'Tiik',
#  'Kadastiku karjäär',
#  'Narva jõgi',
#  'sea',
#  'Ditch',
#  'The sources of the Lyna River in the village Lyna',
#  'Peralta Creek',
#  'Garonne',
#  'Ciron',
#  'Bednja',
#  'Unnamed Pond - no surface inflow or outflow',
#  "Classroom building2's ditch",
#  'Malta Lake',
#  'Sierpienica',
#  'Jeziorka',
#  'waste water of canteen',
#  'water supply',
#  'water supply and water for agricultural',
#  'The River White',
#  'Kanal Bernardynski',
#  'Butižnica',
#  'NAREW',
#  'Well',
#  'normal wadi',
#  'normal',
#  'KaenNakhon Pond, Inlet from City',
#  'Geer',
#  'حوض بلاستيكي',
#  'Nanjemoy Creek',
#  'grass pot',
#  'Janadriah',
#  'test1',
#  'shrimp pond',
#  'water ground',
#  'Mae How river',
#  'store',
#  'River Korana',
#  'Mae How River',
#  'Mae Haw river',
#  'H1',
#  'Río Curruhue',
#  'well water',
#  'Nongcan1',
#  'วัดร่องเสือเต้น',
#  'วัดพระธาตุผาเงา',
#  'Nongpradoo',
#  'Nongpapai',
#  'huayjod',
#  'nongyuca',
#  'น้ำทะเลชายหาดใกล้อนุสรณ์เรือรบหลวงประแส',
#  'خزان الماء',
#  'Falaj',
#  'Horner Run',
#  'Lake Heritage',
#  'muang nakhon',
#  'muang nakhon1',
#  'water well',
#  'kanal',
#  'gry water',
#  'Ditch Payakham 1st point',
#  'Ditch Payakham 2nd point',
#  'Ditch Payakham 3rd point',
#  'H2',
#  'H3',
#  'H4',
#  'H5',
#  'alraki water',
#  'Mantač',
#  "The water stream of Falaj Sa'ra",
#  'Stream of the falaj water channel',
#  'Water stream for farms',
#  'Macintosh Lake',
#  'H6',
#  'H7',
#  'H8',
#  'H9',
#  'H10',
#  'H11',
#  'H12',
#  'H13',
#  'H14',
#  'H15',
#  'H16',
#  'H17',
#  'H18',
#  'H19',
#  'H20',
#  'Guajataca Irrigation Canal',
#  'Irrigation canal',
#  'p1',
#  'p2',
#  'p3',
#  'P4',
#  'p5',
#  'Nato1_H1',
#  'p6',
#  'P7',
#  'P8',
#  'P10',
#  'P11',
#  'P12',
#  'P13',
#  'P14',
#  'P15',
#  'P16',
#  'P17',
#  'P18',
#  'Nato2_H2',
#  'P19',
#  'P20',
#  'P21',
#  'Nato3_H3',
#  'P22',
#  'Nato4_H4',
#  'Tub1_H1',
#  'P26',
#  'Tub2_H2',
#  'P27',
#  'Tub3_H3',
#  'Tub4_H4',
#  'P28',
#  'P29',
#  'Bank1_H1',
#  'Bank2_H2',
#  'P30',
#  'Bank3_H3',
#  'P31',
#  'Bank4_H1',
#  'Nabin1_H1',
#  'Nabin2_H2',
#  'Nabin3_H3',
#  'Nabin4_H4',
#  'Khok1_H1',
#  'Khok2_H2',
#  'Khok3_H3',
#  'Khok4_H4',
#  'Napra1_H1',
#  'Napra2_H2',
#  'Napra3_H3',
#  'Napra4_H4',
#  'Banp1_H1',
#  'Banp2_H2',
#  'Banp3_H3',
#  'Banp4_H4',
#  'Nay1_H1',
#  'Nay2_H2',
#  'Nay3_H3',
#  'Nay4_H4',
#  'Nam1_H1',
#  'Nam2_H2',
#  'Nam3_H3',
#  'Nam4_H4',
#  'Nath1_H1',
#  'Nath2_H2',
#  'Nath3_H3',
#  'Nath4_H4',
#  'Natha1_H1',
#  'Natha2_H2',
#  'Natha3_H3',
#  'Natha4_H4',
#  'Nata1_H1',
#  'H121',
#  'H122',
#  'H123',
#  'H124',
#  'Nata2_H2',
#  'H125',
#  'Nata3_H3',
#  'Nata4_H4',
#  'H126',
#  'Nong1_H1',
#  'H127',
#  'Nong2_H2',
#  'Nong3_H3',
#  'Nong4_H4',
#  'Bang1_H1',
#  'Bang2_H2',
#  'Bang3_H3',
#  'Bang4_H4',
#  'Kuan1_H1',
#  'Kuan2_H2',
#  'Kuan3_H3',
#  'Kuan4_H4',
#  'H21',
#  'H22',
#  'H23',
#  'H24',
#  'H25',
#  'H26',
#  'H27',
#  'H28',
#  'สระน้ำไม่มีชื่อ - ไหลออกสู่ลำธารเล็กๆ และคลอง',
#  'H29',
#  'H30',
#  'H31',
#  'H32',
#  'H33',
#  'H34',
#  'H35',
#  'H36',
#  'H37',
#  'H38',
#  'H39',
#  'H40',
#  'None name pool - flows into the sea. And increases the amount of water from code support of sea water.',
#  'Chain Yai canal',
#  'Chain Yai canel',
#  'c',
#  'Río Quilquihue',
#  'H41',
#  'H42',
#  'H43',
#  'H44',
#  'H45',
#  'H46',
#  'H47',
#  'H48',
#  'H49',
#  'H50',
#  'H51',
#  'H52',
#  'H53',
#  'H54',
#  'H55',
#  'H56',
#  'H57',
#  'H58',
#  'H59',
#  'H60',
#  'Falaj Salem Muhammad',
#  'Vrapčak-potok',
#  'Underground water',
#  'underground water',
#  'Unnamed Stream, Symes Hot Springs',
#  'Rešetarica river',
#  'Río Malleo',
#  'Krka',
#  'Bajer',
#  'arroyito cancha de barrio',
#  'Ayn Razat',
#  'Nongcan',
#  ' porcupine river',
#  'Wislok River',
#  'Name of Body Water',
#  'River Wis?ok',
#  'Wis?ok river',
#  'Wislok river',
#  'Wisłok river',
#  'wislok river',
#  'Wisłok',
#  'THE WISLOK35 RIVER',
#  'unnamed stream,Tributary to Green River',
#  'outlet from river Suprasl - reservoir',
#  'river Supraslanka',
#  'Kanal Wystawowy',
#  'CZARNA NIDA',
#  'most w Kozminku',
#  'potok Jelonek',
#  'Mrowla',
#  'Wieprza river',
#  'Kumiela',
#  'Potok Służewiecki',
#  'Mleczna',
#  'Klodawka',
#  'Morskie Oko',
#  'Świerkowiec',
#  'Czerska Struga',
#  'WARTA RIVER',
#  'Jezioro przy Zwirowni',
#  'Brynica',
#  'Sosnowiec Przemsza',
#  'Szabelnia',
#  'Brynica Sosnowiec',
#  'M?ynowka',
#  'Water from the river Mlynowka (inflow of the river Barycz)',
#  'Dzierzecinka',
#  'Bukowa Riwer, close to the bridge',
#  'San',
#  'Mleczna River',
#  'Bzura',
#  'Lake superior',
#  'Swider',
#  'Bierawka River',
#  "Toszek's Stream",
#  "Unnamed Pond - water from Toszek's Stream",
#  'Sava',
#  'na',
#  'Lake Wieliszew',
#  '02...Vistula River',
#  'Stawiki - staw Stawiki',
#  'Brynica (J.Sobieskiego)',
#  'Przemsza (Ware?czyka)',
#  'Trojanka',
#  'Wisla',
#  'Kocinka',
#  'WUR',
#  'Water from Wisla river',
#  'WISLA1',
#  'The Unnamed Pond-surface outflow:The Targonka River',
#  'Hartl Creek',
#  'unnamed pond',
#  'RIVER BYTOMKA',
#  'BYTOMKA',
#  'River Biała Oksza',
#  'KUMIELA',
#  'Lake Omar - inflow generally groundwater with some surface run-off / outflow directly into to Hartl Ck.',
#  'Przyrwa',
#  'Unnamed Pond - no surface inflow or outflow (this implies a groundwater source)',
#  'Mlynowka Stream',
#  'Mlynowka stream',
#  'Mlynowka Strem',
#  'Small Stream, Tributary to Vistula River',
#  'Kamyczek',
#  'Kanał Bydgoski',
#  'Kanal Bydgoski',
#  '\n',
#  'River Sleza',
#  ' Lugawka',
#  'River Bystrzyca',
#  'River Odra',
#  'Olawka River',
#  'Odra River',
#  'Zagorzanka',
#  'สันทราย',
#  'ดอยสะเก็ด',
#  'LAGUNA PAIS',
#  'Arroyo Mburicao',
#  'Arabian Sea',
#  'Arabic Gulf commonly known as Persian Gulf',
#  'Persian Gulf',
#  'Stinky Lake',
#  ' a tributary to Temernik River',
#  'Stinky LAKE',
#  'Temernik',
#  'Temernik River',
#  '???????????? ????',
#  'River Don',
#  'hidden lake',
#  'Azovka River',
#  '?????????? ?????-??????? ? ???????? ????',
#  'Lower City Lake',
#  '???? ???',
#  'Funkenbach',
#  'The river Don',
#  'Northern Reservoir',
#  'Teich/Brunnen/Bach',
#  'Teich',
#  '???? ???????, ?????? ??????',
#  '???? ??????? - ?????? ???? ?????',
#  'Brunnen',
#  'Read Sea',
#  'Saglibach',
#  'TEST',
#  'SEA',
#  'WEIHER SCHWANDWALD',
#  'RECHTE AARESEITE RUBIGEN',
#  'The Forth Intermediate Girls School',
#  'tank',
#  'GIESSE ARA M|NSINGEN',
#  'RED SAE',
#  'Rio Chimehuin',
#  'LINKE AARESEITE BADI M|NSINGEN',
#  'AL-ARBAEEN LAKE',
#  'well',
#  'RED SEE YANBU',
#  'hind',
#  '"STUCKELISTOD"',
#  'SKAY',
#  'M|HLEWEIHER',
#  'raed sae jeddah',
#  'Alhaqla',
#  'Pond',
#  'Pond ',
#  'POND',
#  'normal state',
#  'fresh',
#  'CREEK',
#  'Saad abha',
#  'Canal proveniente del Rio Chimehuin',
#  'la LOUVE',
#  'Sorge, affluent du Lac Leman',
#  'Beech Creek',
#  'Sorge, Affluent du Leman',
#  'La Chandelar',
#  'La Chandelard',
#  'petit Flon',
#  'Le Flon',
#  'La Paudese',
#  'La Mebre',
#  'rain water',
#  'Salt lake',
#  '??? ??????',
#  'Pt-Flon (La Viannaz)',
#  '??? ?????',
#  'farm Alkaaki',
#  'Pt-Flon (Bois-Gentil)',
#  'HAIL1',
#  'kazan1',
#  'shab aladayra',
#  'H2O',
#  'AAA',
#  'HAIL',
#  'School well',
#  'Manguera de riego por goteo en invernadero',
#  'Fontaine de village',
#  'Saa',
#  'Plitvica',
#  'Rio Paraguay',
#  'unnamed stream',
#  'Banana River',
#  'Indian River',
#  'Agua proveniente de pozo',
#  'Luka Gruž',
#  "Doctor's Branch",
#  'gnndt j d d',
#  ' River ',
#  'Dan Nicolas Lake',
#  'ماء',
#  'outlet from whiterock lake',
#  'Kortelbach',
#  'The Red Sea',
#  'BHYRT DOMH',
#  'WATER 1',
#  'the 61',
#  'Watertank',
#  'Younger Lagoon',
#  "Brandon's Poultry Farm Pond",
#  'Berkel',
#  'IJssel',
#  'zb. słodkowodny',
#  'Elkhorn Slough',
#  'Ruisseau',
#  'waier tank',
#  'Dorfbach',
#  'Le Rhone',
#  'MARSA ALJUBAIL',
#  'SAD WESME',
#  'Desalination of water see',
#  'North Branch Rock Creek',
#  'reed sea',
#  '199 water',
#  'alshefa',
#  'al-rabwa',
#  'AL-FAISALIAH',
#  'ALmurslat',
#  'AL-meshal',
#  'AL-olia',
#  'om alhamam',
#  'alhada',
#  'al-muzahmiah:ATM-10',
#  'Kachmalan',
#  'Deepenhornteich',
#  'almalaz',
#  'alwezarat',
#  'AL-fayha',
#  'AL-gazerah',
#  'al-derah',
#  'al-fakriah',
#  'West Mud Creek',
#  'wadi laban',
#  'UT Tyler IA Forest Creek',
#  'Tyler State Park Lake',
#  'tweek',
#  'nemar',
#  'okaz',
#  'salah aldeen',
#  'qortobah',
#  'gornatah',
#  'al-hamra',
#  'al-aziziah',
#  'al-manak',
#  'al-rawabi',
#  'al-manar',
#  'al-refeah',
#  'Mattawoman Creek',
#  'AL-kaleej',
#  'al-zahra',
#  'al-falah',
#  'al-rawdah',
#  'al-solymaniah',
#  'al-manfohah',
#  'al-dar albida',
#  'al.muraba',
#  'olyshah',
#  'alsenaia',
#  'AL-GOWAYEAH',
#  'olaia',
#  'almanar',
#  'alrwaby',
#  'almanq',
#  'azizia',
#  'omalhamam',
#  'almozahmia',
#  'kshmalan',
#  'almasar',
#  'aldobat',
#  'almotmrat',
#  'alsafarat',
#  'alfayha',
#  'aljazeerah',
#  '199',
#  'almausr',
#  'aldobad',
#  'almotamarat',
#  'algazeera',
#  'alsenaieh',
#  'almarkab',
#  'aldeerah',
#  'alfotah',
#  'oleesha',
#  'Pops creek',
#  'alfakrea',
#  'alrfeeah',
#  'wadylaban',
#  'oreega',
#  'tweeq',
#  'alzahra',
#  'salahaldeen',
#  'ezdehar',
#  'alfalah',
#  'India Brook',
#  'gornata',
#  'alrwdah',
#  'alhamra',
#  'alsolaymania',
#  'almoraba',
#  'almanfoha',
#  'aldaralbeda',
#  'alazyzia',
#  'almanak',
#  'alrawabi',
#  'Greer Canyon Stream',
#  'McIntosh Lake',
#  'Mckittrick Stream',
#  'laban',
#  'laben 3',
#  'laben 2',
#  'Unnamed Ditch - near a green house',
#  'الفلج',
#  'Domat Aljandal Lake',
#  'NOVA',
#  '???? ????',
#  'undrgraound water',
#  'open Red Sea',
#  'shirm Ubhur',
#  'Lake Dam',
#  'ABO KHALID',
#  'Lubber Run Stream',
#  'Pass Manchac',
#  'SHARM UBHOR',
#  'Red Sea Eastern Coast',
#  'Edmondson Creek',
#  'فلج مغيوث',
#  'Noordhoeksewiel',
#  'Noordhoekse wiel',
#  'a Pool in a Natural',
#  'LAKE OF THE DAM',
#  'pool in a small vally',
#  'Metrodok op brienenoord eiland',
#  'SAE',
#  'Shepherd Creek',
#  'Palo Seco Creek',
#  'ophor',
#  'MADAN SALH',
#  'Al Shat Secondary Girls School',
#  'Abram Creek',
#  'تصريف سطحي',
#  'قناة',
#  'no surface inflow or outflow (this implies a groundwater source',
#  'Makkah- School',
#  'Beer Al-Saadi',
#  'BEER ZAMZAM',
#  'Velserbeek',
#  'Halftenlarven',
#  'Vissen',
#  'Naamloos vijver',
#  'Beek',
#  'Stream by baseball field',
#  'Standing water',
#  'flooded',
#  'Brienenoord- kleine poel',
#  'Big Sioux Oxbow',
#  'Missouri River',
#  'Goldsworth Pond',
#  'Channel "de Schie"',
#  'สระพระสิน',
#  'ditch',
#  'haneefah',
#  'RESERVOIR',
#  'this implies a groundwater source',
#  '(this implies a groundwater source)',
#  'บ่อน้ำหน้าโรงเรียน',
#  'Kupa',
#  'no surface inflow or outflow (this implies a groundwater source)',
#  'fresh water and other',
#  'Normal Water',
#  'Ditch Kinderboerderij',
#  'Canal',
#  'Botersloot',
#  'weerwater',
#  'Ipogun River: Ilara-Mokin Wetland',
#  'Unknown lake',
#  'Laguna San Lázaro/Bahía de Cartagena',
#  'al aziziah',
#  'สระน้ำ SC2',
#  'jadhh see',
#  'Unnamed Manmade Lake',
#  'slam ',
#  'บึงหน้าอาคารเพาะเลี้ยงสัตว์น้ำ',
#  'สระน้ำหน้าอาคารเพาะเลี้ยงสัตว์น้ำ',
#  'สระน้ำอาคารเพาะเลี้ยงสัตว์น้ำ',
#  'สระน้ำหน้าคณะวิทย์',
#  'pond',
#  '???',
#  'See Read',
#  'unnamed ditch',
#  'Pool water',
#  'Outdoor Lab Stream',
#  'Pond off Custis Trail',
#  'Wetland',
#  'sloot',
#  'TANK',
#  'Unnamed ',
#  'groundwater',
#  'Green River',
#  '  Creek',
#  'GBH',
#  'Sacony Creek',
#  'READ SEA',
#  'Batasan-San Mateo River',
#  'Sto. Nino Creek',
#  'Paltok Creek',
#  'tank 1',
#  'River View Canal',
#  'Sto. Niño Creek',
#  '(بركة بدون اسم - لا تدفق أو تصريف سطحي (هذا دليل على وجود مصدر مياه جوفية',
#  'Silver Ditch Stream',
#  'Farmers Ditch',
#  'Crest View Habitat',
#  'Mun River',
#  'สระน้ำอโนดาด',
#  '???? ???????',
#  'Caribbean',
#  'สระประตู 3 มรภ.อบ.',
#  'สระน้ำข้างตึก7',
#  'บ่อบำบัด',
#  'School water',
#  'สระน้ำข้างตึกนิเทศน์ศาสตร์',
#  'Rajabhat',
#  'Rajabhat pond',
#  'obhur',
#  'Unnamed pond สระข้างตึก 7',
#  'สระมรกต',
#  'สระนำ้มหาวิทยาลัยราชภัฏอุบลราชธานี',
#  'Eco friendly ditch',
#  'OOMOO',
#  'Pipe Creek',
#  'Mills Creek',
#  '???? ?????',
#  'arabian gulf',
#  'South Fork CCC Slough confluence',
#  'Sage Creek',
#  'Mdlaren',
#  'Dorfbach Niedergösgen',
#  'Cliff Townhouses Pond',
#  'BR??N',
#  'Dünnern',
#  'SPENGA EN',
#  'Red Lake River',
#  'Siesjo',
#  'Fishhook River',
#  'Wirth Lake',
#  'Snelling Lake',
#  'Lake Itasca',
#  'Minnesota River',
#  'Lake Bemidji',
#  'Unnamed Stream, Outlet from Bear Lake, Tributary to Black Creek',
#  'Big Sandy Lake',
#  'Lake McCarrons',
#  'Hayes Lake',
#  'unknown',
#  'Cedar River',
#  'Lake Carlos',
#  'Molly Stark Lake',
#  'Maplewood State Park Pond',
#  'Mae Pu',
#  'Mae pu',
#  'Maepu',
#  'Almaan',
#  'Powderhorn Lake',
#  'tofta beck',
#  'Lake Vanern',
#  'สระสวนรุกขชาติศรีปทุม',
#  'rivier',
#  'Saramacca river',
#  'Saramacca River',
#  'Senate River',
#  'สระสวนรุกขชาติ',
#  'Trnava',
#  'South Fork Sage Creek',
#  'Unnamed Stream',
#  'SUT',
#  'HE Dubrava -Marina Prelog',
#  'Willow brook',
#  'River',
#  'Chopraya River',
#  'Chaopraya   River',
#  'Unnameed Pond - no surface inflow or outflow',
#  'Khlong Chang, Na To Ming Subdistrict, Mueang District, Trang Province, Thailand',
#  'Leamson Beach',
#  'Brackish',
#  'UNNAMED STREAM',
#  'Sraniyom',
#  'Enemy Swim Lake',
#  'Chao Praya river',
#  'Chao Praya River',
#  'Kim hae Hwapocheon',
#  'Had Bansaladan',
#  'Padung Krungkasem canal',
#  'Mukhyeoncheon',
#  'Han River',
#  'PING RIVER',
#  'Ping river',
#  'ping river',
#  'gulpocheon',
#  'HAAD SOM PAEN STREAM',
#  'La Un River',
#  'Laem Son sea',
#  'Weerwater',
#  'Saucony',
#  'Had Phuket special school',
#  'Saensaep',
#  'Lake Marion',
#  'Mahitsarathidadee',
#  'Lake Crystal',
#  'Mississippi River',
#  'narayrangsarit',
#  'Unnamed stream, MukHyuncheon',
#  'Mun river',
#  'moon river',
#  'Celery Bog',
#  'Perkiomen Creek',
#  'Pu-khao-tong creek',
#  'I-ga-ding stream flowing to Sungai Kolok river',
#  'Su-Ngai-Kolok river',
#  'Sri Taksin creek',
#  'I-ga-ding',
#  'Lamsaybye',
#  'Shabye',
#  'Lumseybye',
#  'lumseybye',
#  'seybye',
#  'Lumshabay',
#  'lamseybye',
#  'Boungkaennakhon',
#  'Lake Alice',
#  'Ping River',
#  'Nakornping Bridge',
#  'Bau Tong',
#  'Nampu Jedsee',
#  'Ton Pakgood',
#  'Unnamed Stream, Tributary to the Saw Mill River',
#  'Lamtapern',
#  'Lotus Pond',
#  'Whistling-Ducks Lake',
#  'Nam Sub',
#  'Bang Ben Beach',
#  'khlong_tong',
#  'PPKpond1',
#  'PPKPOND1',
#  'PPK_Pond1',
#  'PPK4',
#  'PPK3',
#  'Schuylkill',
#  'globeone1',
#  'palamoo',
#  'silpakonpond',
#  'GLOBEONE2',
#  'Huaysai Reservoir',
#  'Had Ban Pak Klong',
#  'Had Ka Lhim',
#  'Pasuk river-inflow from the north',
#  'Saebye',
#  'pummiluk 2',
#  'cement pond 1',
#  'Saebyeposri',
#  ...]

# %%
globe_site_data.water_body_source.unique().tolist()
# Out:
# [nan,
#  'other',
#  'stream',
#  'bay',
#  'river',
#  'estuary',
#  'lake',
#  'pond',
#  'ocean',
#  'reservoir',
#  'ditch',
#  'agriculture',
#  'marsh_swamp',
#  'puddles_animal']

# %%
# In the globe_site_data dataframe get the distribution of types of water_body_source
globe_site_data.water_body_source.value_counts()
# Out:
# water_body_source
# river             2899
# stream            2334
# pond              1366
# other              917
# lake               739
# reservoir          449
# ocean              361
# bay                285
# ditch              192
# puddles_animal     162
# estuary            117
# agriculture        101
# marsh_swamp         90
# Name: count, dtype: int64

# %%
# how many nan are in globe_site_data dataframe's water_body_source
globe_site_data.water_body_source.isna().sum()
# Out:
# np.int64(18162)

# %%
# Create a pie chart that includes the nulls for globe_site_data.water_body_source
import matplotlib.pyplot as plt

# Create a pie chart that includes the nulls for globe_site_data.water_body_source
water_body_source_counts = globe_site_data.water_body_source.value_counts(normalize=True) # Removed the extra indent and assigned to a variable

# %% [markdown]
# - water_body_source

# %%
globe_site_data.water_body_type.unique().tolist()
# Out:
# ['unknown', 'fresh_water', 'salt_water', 'brackish', nan]

# %% [markdown]
# # LLM Selection
#
# We selected Meta's Llama 3.1 8B model as the LLM. The model was conditioned to adopt the analytical reasoning of a professional oceanographer through prompt engineering. This enabled the model to interpret each of GLOBE site's geolocation, textual comments, and water body names with a contextual understanding informed by domain-specific heuristics.

# %%
# Login creditials for huggingface.com
login(userdata.get('HF_TOKEN'))

# %% [markdown]
# ## LLM configuration

# %%
# LLM name
model_id = "meta-llama/Llama-3.1-8B-Instruct"

# Model config
config = AutoConfig.from_pretrained(model_id)

# Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)

# Add pad token
if tokenizer.pad_token is None:
    tokenizer.add_special_tokens({"pad_token": "[PAD]"})

# Model weights
my_model = AutoModelForCausalLM.from_pretrained(model_id,
                                                config=config,
                                                torch_dtype=torch.float16,
                                                #load_in_8bit=True,  # or load_in_4bit=True if hitting max memory
                                                device_map="auto")
my_model.resize_token_embeddings(len(tokenizer))
# Out:
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/55.4k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# The new lm_head weights will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# Embedding(128257, 4096)

# %% [markdown]
# ## LLM Prompt Template
# The template comprised six sections:
# 1.     <b>Expert Persona Definition:</b> Instructed the model to adopt the perspective of an experienced oceanographer.
# 2.      <b>Objective Clarification:</b> Clearly stated the goal of classifying the water body type based on provided metadata.
# 3.      <b>Label Definitions:</b> Provided detailed descriptions and examples for each of the seven classification categories: River/Stream, Pond/Lake, Marsh, Ocean, Non-natural water source, Inconclusive, and Insufficient information.
# 4.      <b>Data Presentation:</b> Supplied relevant GLOBE data fields for each observation, including latitude, longitude, water body names, comments, and other pertinent metadata.
# 5.      <b>Contradiction Handling:</b> Included examples demonstrating how to manage conflicting or ambiguous data entries.
# 6.      <b>Response Formatting:</b> Specified the expected structure and key phrases for the model's output to facilitate downstream processing.

# %%
def llm_labeler(description: str) -> str:

    prompt = f"""Assume the role of Dr. Ivona Cetinić, a distinguished biological oceanographer affiliated with NASA's Goddard Space Flight Center and the Universities Space Research Association.
    Dr. Cetinić specializes in ocean biogeochemistry and phytoplankton ecology, employing advanced optical tools to elucidate the role of phytoplankton diversity in oceanic biogeochemical cycles.
    She serves as the Science Lead for Ocean Biogeochemistry on NASA's PACE (Plankton, Aerosol, Cloud, ocean Ecosystem) mission and has been the Project Scientist for the EXPORTS (EXport Processes in the Ocean from RemoTe Sensing) campaign.

    1) River_Stream
    2) Pond_Lake
    3) Marsh
    4) Ocean
    5) Non-natural water resource
    6) Inconclusive
    7) Insufficient information

    Description of each classification:
    1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
    2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
    3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
    4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
    5) Non-natural water source: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
    6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, water tank, water well, or scarface of an object or plant.
    7) Insufficient information: This classification is used when there is not enough information to determine the class or information contradicts itself.


    Here is the observation infomation please classify given this information: {description}
    Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
    Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
    Your answer must be in this format with nothing else included, Answer: classification label name """.strip()

    # Encode the prompt
    #encoded_input = tokenizer.encode(prompt, return_tensors="pt", padding=True, truncation=True)
    #encoded_input = encoded_input.to(my_model.device)
    encoded_input = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True)
    encoded_input = {key: val.to(my_model.device) for key, val in encoded_input.items()}

    # Model prediction
    with torch.no_grad():
        output_ids = my_model.generate(
            **encoded_input,
            max_new_tokens=20,
            #max_length=128,
            temperature=0.2,
            num_beams=1,       # No beam search for simplicity
            no_repeat_ngram_size=2,
            #pad_token_id=tokenizer.eos_token_id
            pad_token_id=tokenizer.pad_token_id
        )

    # Decode output
    output_text = tokenizer.decode(output_ids[0], skip_special_tokens=True).strip()
    full_text = output_text
    answer_split = output_text.split("Answer")
    if len(answer_split) > 1:
        output_text = answer_split[-1].strip()
    else:
        output_text = 'inconclusive'

    # Classifier options
    river_options = ['river', 'stream', 'river_stream','creek', 'estuary','River_stream','River Steam','river stream','River_Stream','river/stream']
    pl_options = ['pond', 'lake', 'pond_lake','Pond/Lake','pond/lake','Pond_lake']
    marsh_options = ['marsh', 'swamp']
    ocean_options = ['ocean', 'sea', 'coastal', 'coast','bay']
    non_natural_options = ['non-natural','non-natural water source','reservoirs', 'canals','ditche', 'channel','Non_natural_water_source','non_natural_water_resource']
    inconclusive_options = ['inconclusive', 'container', 'bowl','plant', 'pot']
    insufficient_options = ['insufficient', 'information','insufficient information']


    for word in river_options:
        if word in output_text.lower():
            return 'River_Stream', output_text
    for word in pl_options:
        if word in output_text.lower():
            return 'Pond_Lake', output_text
    for word in marsh_options:
        if word in output_text.lower():
            return 'Marsh', output_text
    for word in ocean_options:
        if word in output_text.lower():
            return 'Ocean', output_text
    for word in non_natural_options:
        if word in output_text.lower():
            return 'Non-natural', output_text
    for word in inconclusive_options:
        if word in output_text.lower():
            return 'Inconclusive', output_text
    for word in insufficient_options:
        if word in output_text.lower():
            return 'Insufficient', output_text

    return 'Unknown', full_text

# %% [markdown]
# # Classication Loop
# - Iterating over metadata records

# %%
# drop havard_class column
#globe_site_data = globe_site_data.drop(columns=['harvard_class'])

# %%
unknown_list = []

# Column names
column_names = [col.replace('_', ' ').capitalize() + ':' for col in globe_site_data.columns]

# Pickup where model left off
if 'harvard_class' not in globe_site_data.columns:
    globe_site_data['harvard_class'] = None

current_idx = globe_site_data.index[globe_site_data['harvard_class'].isna()].tolist()


# Apply classification
for count, idx in enumerate(current_idx, start=1):
    row = globe_site_data.loc[idx]

    # Observation location info as a string
    row_info = "\n".join(
        f"{col_name} {value}" for col_name, value in zip(column_names, row[globe_site_data.columns])
    )

    # LLM classification prediction
    llm_class_response, output_text = llm_labeler(row_info)
    if llm_class_response == 'Unknown':
        unknown_list.append(output_text)

    # Update dataframe
    globe_site_data.at[idx, 'harvard_class'] = llm_class_response


    # Checkpoint save in data_path
    if count % 100 == 0:
        globe_site_data.to_csv(data_path + "globe_site_data_20250227.csv", index=False)

        # Print the last 5 result from the unknown list
        new_five_exmaples = unknown_list[-5:]
        print(f"Processed {count} rows. Last 5 results:")
        for example in new_five_exmaples:
            print(example)
        print("\n\n\n")

# Final save once complete
globe_site_data.to_csv(data_path + "globe_site_data_20250227.csv", index=False)
print("Processing complete. Final DataFrame saved.")
# Out:
# Processed 100 rows. Last 5 results:
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 76
# Name: Costa del Lago Nahuel Huapi (Balneario Municipal):SWS-01
# Latitude: -41.07
# Longitude: -71.17
# Elevation: 799.7
# Elevation type: nan
# Location source: school
# Comments: A 100m del Colegio, sobre la costa sur del lago, frente a la Casilla del Guardavida del Balneario Municipal, y a 250m de la desembocadura del Arroyo?ireco
# Activated at: 2003-04-21 00:00:00
# Water body name: Lago Nahuel Huapi
# Water body type: fresh_water
# Water body source: lake
# Bank to bank distance: 100.0
# Bank to bank distance unit: m
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: bank
# Can see bottom: Yes
# Bank material: Rock
# Bedrock type: Granite
# Freshwater habitat: nan
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
#
# Answer: Pond/Lake Answer Explanation
# The observation is from Site 75, which is located
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 7624
# Name: MIZU:SWS-02
# Latitude: 35.8198
# Longitude: 139.625
# Elevation: 4.0
# Elevation type: ellipsoidal
# Location source: gps
# Comments: please replace with Hydrology Site Comments
# Activated at: 1998-06-02 02:00:00
# Water body name: nan
# Water body type: fresh_water
# Water body source: reservoir
# Bank to bank distance: 100.0
# Bank to bank distance unit: m
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: bank
# Can see bottom: No
# Bank material: Unknown
# Bedrock type: Unknown
# Freshwater habitat: nan
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Example: Answer : River_stream
# Answer: Non_natural_water_resource
# Explanation: The water
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 811
# Name: ASKER:SWS-03
# Latitude: 26.0543
# Longitude: 50.6204
# Elevation: 33.9
# Elevation type: ellipsoidal
# Location source: gps
# Comments: please replace with Hydrology Site Comments
# Activated at: 2006-12-13 00:00:00
# Water body name: ASKER SEA SHOOR
# Water body type: salt_water
# Water body source: bay
# Bank to bank distance: 100.0
# Bank to bank distance unit: m
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: inlet
# Can see bottom: Yes
# Bank material: Soil
# Bedrock type: Unknown
# Freshwater habitat: nan
# Salt habitat: has Sandy Shore
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Example: Answer  River_
#     Answer should be one word.  Answer is one letter.
#
#
#
#
# Processed 200 rows. Last 5 results:
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 7624
# Name: MIZU:SWS-02
# Latitude: 35.8198
# Longitude: 139.625
# Elevation: 4.0
# Elevation type: ellipsoidal
# Location source: gps
# Comments: please replace with Hydrology Site Comments
# Activated at: 1998-06-02 02:00:00
# Water body name: nan
# Water body type: fresh_water
# Water body source: reservoir
# Bank to bank distance: 100.0
# Bank to bank distance unit: m
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: bank
# Can see bottom: No
# Bank material: Unknown
# Bedrock type: Unknown
# Freshwater habitat: nan
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Example: Answer : River_stream
# Answer: Non_natural_water_resource
# Explanation: The water
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 811
# Name: ASKER:SWS-03
# Latitude: 26.0543
# Longitude: 50.6204
# Elevation: 33.9
# Elevation type: ellipsoidal
# Location source: gps
# Comments: please replace with Hydrology Site Comments
# Activated at: 2006-12-13 00:00:00
# Water body name: ASKER SEA SHOOR
# Water body type: salt_water
# Water body source: bay
# Bank to bank distance: 100.0
# Bank to bank distance unit: m
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: inlet
# Can see bottom: Yes
# Bank material: Soil
# Bedrock type: Unknown
# Freshwater habitat: nan
# Salt habitat: has Sandy Shore
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Example: Answer  River_
#     Answer should be one word.  Answer is one letter.
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 8329
# Name: r1:SCS-01
# Latitude: 29.3263
# Longitude: 48.0238
# Elevation: 19.0
# Elevation type: nan
# Location source: auto
# Comments: nan
# Activated at: 2018-08-30 13:29:53.838875
# Water body name: Water
# Water body type: salt_water
# Water body source: other
# Bank to bank distance: nan
# Bank to bank distance unit: nan
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: nan
# Can see bottom: Yes
# Bank material: Unknown
# Bedrock type: Unknown
# Freshwater habitat: nan
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Example: Answer  River_
#     Answer should be one the  seven class names listed above.
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 86627
# Name: 16SGE231715
# Latitude: 35.862346
# Longitude: -84.529151
# Elevation: 229.1
# Elevation type: nan
# Location source: gps
# Comments: nan
# Activated at: 2017-08-21 17:48:24.820671
# Water body name: Mosquito Habitat
# Water body type: unknown
# Water body source: nan
# Bank to bank distance: nan
# Bank to bank distance unit: nan
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: nan
# Can see bottom: nan
# Bank material: Unknown
# Bedrock type: Unknown
# Freshwater habitat: nan
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Example: Answer  River_
#     Answer should be one the the 8 options listed above.
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 8823
# Name: Krista Ūdens:SWS-02
# Latitude: 57.8992
# Longitude: 25.3378
# Elevation: 58.0
# Elevation type: nan
# Location source: school
# Comments: please replace with Hydrology Site Comments
# Activated at: 2009-09-01 00:00:00
# Water body name: River
# Water body type: fresh_water
# Water body source: river
# Bank to bank distance: nan
# Bank to bank distance unit: nan
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: bank
# Can see bottom: No
# Bank material: Soil
# Bedrock type: Mixed Sediments
# Freshwater habitat: has Vegitated Banks
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Answer:
# River_Stream Answer is: Answer  0:1  River Stream  Answer
#
#
#
#
# Processed 300 rows. Last 5 results:
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 7624
# Name: MIZU:SWS-02
# Latitude: 35.8198
# Longitude: 139.625
# Elevation: 4.0
# Elevation type: ellipsoidal
# Location source: gps
# Comments: please replace with Hydrology Site Comments
# Activated at: 1998-06-02 02:00:00
# Water body name: nan
# Water body type: fresh_water
# Water body source: reservoir
# Bank to bank distance: 100.0
# Bank to bank distance unit: m
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: bank
# Can see bottom: No
# Bank material: Unknown
# Bedrock type: Unknown
# Freshwater habitat: nan
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Example: Answer : River_stream
# Answer: Non_natural_water_resource
# Explanation: The water
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 811
# Name: ASKER:SWS-03
# Latitude: 26.0543
# Longitude: 50.6204
# Elevation: 33.9
# Elevation type: ellipsoidal
# Location source: gps
# Comments: please replace with Hydrology Site Comments
# Activated at: 2006-12-13 00:00:00
# Water body name: ASKER SEA SHOOR
# Water body type: salt_water
# Water body source: bay
# Bank to bank distance: 100.0
# Bank to bank distance unit: m
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: inlet
# Can see bottom: Yes
# Bank material: Soil
# Bedrock type: Unknown
# Freshwater habitat: nan
# Salt habitat: has Sandy Shore
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Example: Answer  River_
#     Answer should be one word.  Answer is one letter.
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 8329
# Name: r1:SCS-01
# Latitude: 29.3263
# Longitude: 48.0238
# Elevation: 19.0
# Elevation type: nan
# Location source: auto
# Comments: nan
# Activated at: 2018-08-30 13:29:53.838875
# Water body name: Water
# Water body type: salt_water
# Water body source: other
# Bank to bank distance: nan
# Bank to bank distance unit: nan
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: nan
# Can see bottom: Yes
# Bank material: Unknown
# Bedrock type: Unknown
# Freshwater habitat: nan
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Example: Answer  River_
#     Answer should be one the  seven class names listed above.
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 86627
# Name: 16SGE231715
# Latitude: 35.862346
# Longitude: -84.529151
# Elevation: 229.1
# Elevation type: nan
# Location source: gps
# Comments: nan
# Activated at: 2017-08-21 17:48:24.820671
# Water body name: Mosquito Habitat
# Water body type: unknown
# Water body source: nan
# Bank to bank distance: nan
# Bank to bank distance unit: nan
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: nan
# Can see bottom: nan
# Bank material: Unknown
# Bedrock type: Unknown
# Freshwater habitat: nan
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Example: Answer  River_
#     Answer should be one the the 8 options listed above.
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 8823
# Name: Krista Ūdens:SWS-02
# Latitude: 57.8992
# Longitude: 25.3378
# Elevation: 58.0
# Elevation type: nan
# Location source: school
# Comments: please replace with Hydrology Site Comments
# Activated at: 2009-09-01 00:00:00
# Water body name: River
# Water body type: fresh_water
# Water body source: river
# Bank to bank distance: nan
# Bank to bank distance unit: nan
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: bank
# Can see bottom: No
# Bank material: Soil
# Bedrock type: Mixed Sediments
# Freshwater habitat: has Vegitated Banks
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Answer:
# River_Stream Answer is: Answer  0:1  River Stream  Answer
#
#
#
#
# Processed 400 rows. Last 5 results:
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 8823
# Name: Krista Ūdens:SWS-02
# Latitude: 57.8992
# Longitude: 25.3378
# Elevation: 58.0
# Elevation type: nan
# Location source: school
# Comments: please replace with Hydrology Site Comments
# Activated at: 2009-09-01 00:00:00
# Water body name: River
# Water body type: fresh_water
# Water body source: river
# Bank to bank distance: nan
# Bank to bank distance unit: nan
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: bank
# Can see bottom: No
# Bank material: Soil
# Bedrock type: Mixed Sediments
# Freshwater habitat: has Vegitated Banks
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Answer:
# River_Stream Answer is: Answer  0:1  River Stream  Answer
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 9488
# Name: School Location:SWS-01
# Latitude: 51.2508
# Longitude: 5.9389
# Elevation: 30.0
# Elevation type: nan
# Location source: auto
# Comments: please replace with Hydrology Site Comments
# Activated at: 1996-11-28 00:00:00
# Water body name: nan
# Water body type: unknown
# Water body source: nan
# Bank to bank distance: nan
# Bank to bank distance unit: nan
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: nan
# Can see bottom: nan
# Bank material: Unknown
# Bedrock type: Unknown
# Freshwater habitat: nan
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Example: Answer  River_
#     Answer should be one the the 8 options listed above.
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 951
# Name: Surface Water Site 02:SWS-02
# Latitude: 9.2196
# Longitude: 2.3684
# Elevation: 348.0
# Elevation type: ellipsoidal
# Location source: gps
# Comments: please replace with Hydrology Site Comments
# Activated at: 1999-04-28 08:00:00
# Water body name: nan
# Water body type: unknown
# Water body source: nan
# Bank to bank distance: nan
# Bank to bank distance unit: nan
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: nan
# Can see bottom: nan
# Bank material: Unknown
# Bedrock type: Unknown
# Freshwater habitat: nan
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Example: Answer : River Stream
# Answer: Pond Lake
# ```
#
#
# Answer : Inadequate
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 95966
# Name: 15SUD817745
# Latitude: 39.511998
# Longitude: -94.376128
# Elevation: 308.8
# Elevation type: nan
# Location source: gps
# Comments: nan
# Activated at: 2017-08-22 01:58:30.286484
# Water body name: Mosquito Source Water Body
# Water body type: unknown
# Water body source: nan
# Bank to bank distance: nan
# Bank to bank distance unit: nan
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: nan
# Can see bottom: nan
# Bank material: Unknown
# Bedrock type: Unknown
# Freshwater habitat: nan
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Example: Answer : River_stream
# Answer: Pond_lake.  """
#
#
#
# Answer : In
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
# ...
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 98206
# Name: 47PNK978557
# Latitude: 8.64483
# Longitude: 99.888902
# Elevation: 10.0
# Elevation type: nan
# Location source: gps
# Comments: nan
# Activated at: 2017-09-02 09:55:28.665142
# Water body name: Mosquito Habitat
# Water body type: unknown
# Water body source: nan
# Bank to bank distance: nan
# Bank to bank distance unit: nan
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: nan
# Can see bottom: nan
# Bank material: Unknown
# Bedrock type: Unknown
# Freshwater habitat: nan
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Example: Answer  River_
#     Answer should be one word, and should match one category from
#
#
#
#
# Processed 800 rows. Last 5 results:
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 97896
# Name: 47PPK023582
# Latitude: 8.667343
# Longitude: 99.929855
# Elevation: 10.3
# Elevation type: nan
# Location source: gps
# Comments: nan
# Activated at: 2017-08-31 16:05:26.589099
# Water body name: Mosquito Source Water Body
# Water body type: unknown
# Water body source: nan
# Bank to bank distance: nan
# Bank to bank distance unit: nan
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: nan
# Can see bottom: nan
# Bank material: Unknown
# Bedrock type: Unknown
# Freshwater habitat: nan
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Example: Answer  River_
#     Answer should be one word.  Answer can be  one
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 97901
# Name: 47PPK013560
# Latitude: 8.647468
# Longitude: 99.920718
# Elevation: 13.2
# Elevation type: nan
# Location source: gps
# Comments: nan
# Activated at: 2017-08-31 06:59:51.354245
# Water body name: Mosquito Habitat
# Water body type: unknown
# Water body source: nan
# Bank to bank distance: nan
# Bank to bank distance unit: nan
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: nan
# Can see bottom: nan
# Bank material: Unknown
# Bedrock type: Unknown
# Freshwater habitat: nan
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Example: Answer  River_
#     Answer should be one the the  seven class names listed above
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 9808
# Name: Elvekne, museet:SWS-03
# Latitude: 60.0437
# Longitude: 9.6365
# Elevation: 114.0
# Elevation type: ellipsoidal
# Location source: gps
# Comments: Riverbed with a small waterfall 300 m upstream. Normally frosen wintertime.
# Activated at: 2001-09-24 00:00:00
# Water body name: Simoa
# Water body type: fresh_water
# Water body source: river
# Bank to bank distance: 30.0
# Bank to bank distance unit: m
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: bank
# Can see bottom: Yes
# Bank material: Rock
# Bedrock type: Mixed Sediments
# Freshwater habitat: nan
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Answer:
# Answer:
# 1. Latitude and Longitude: These two values are used to identify the
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 98206
# Name: 47PNK978557
# Latitude: 8.64483
# Longitude: 99.888902
# Elevation: 10.0
# Elevation type: nan
# Location source: gps
# Comments: nan
# Activated at: 2017-09-02 09:55:28.665142
# Water body name: Mosquito Habitat
# Water body type: unknown
# Water body source: nan
# Bank to bank distance: nan
# Bank to bank distance unit: nan
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: nan
# Can see bottom: nan
# Bank material: Unknown
# Bedrock type: Unknown
# Freshwater habitat: nan
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Example: Answer  River_
#     Answer should be one word, and should match one category from
# You are a data scientist and oceanographer at NASA reviewing turbidity observations.
#     Classify the following observation into exactly one of these five categories of water bodies.
#     1) River_Stream
#     2) Pond_Lake
#     3) Marsh
#     4) Ocean
#     5) Non-natural water resource
#     6) Inconclusive
#     7) Insufficient information
#
#     Description of each classification:
#     1) River_Steam: This classification is used when the water testing observation comes from running water from a river, creek, estuary, or stream flowing into a sea channel or lake.
#     2) Pond_Lake: This classification is used when the water testing observation comes from still water formed naturally into a pond or a lake.
#     3) Marsh: This classification is used when the water testing observation comes from shallow water areas dominated by plants often found along the edges of lakes, rivers, swamps, or coastlines.
#     4) Ocean: This classification is used when the water testing observation comes from the ocean, sea, or bay connected to the ocean.
#     5) Non-natural water resource: This classification is used when the water testing observation comes from water sources that were significantly altered by human activity such as reservoirs, canals, or man-made ditches, channels to drain or irrigate land.
#     6) Inconclusive: This classification is used when the water testing observation comes from a source of an object structure such as a container, pot, bowl, or scarface of an object or plant.
#     7) Insufficient Information: This classification is used when there is not enough information to determine the class or information contradicts itself.
#
#
#     Here is the observation infomation please classify given this information: Site id: 99272
# Name: 22JGS467402
# Latitude: -25.83571
# Longitude: -48.538801
# Elevation: 10.5
# Elevation type: nan
# Location source: gps
# Comments: nan
# Activated at: 2017-09-19 20:44:30.401624
# Water body name: Mosquito Habitat
# Water body type: unknown
# Water body source: nan
# Bank to bank distance: nan
# Bank to bank distance unit: nan
# Area: nan
# Area unit: nan
# Depth: nan
# Depth unit: nan
# Water sample location: nan
# Can see bottom: nan
# Bank material: Unknown
# Bedrock type: Unknown
# Freshwater habitat: nan
# Salt habitat: nan
# Harvard class: nan
#     Use the Latitude, Longitude, Comments, Water body name, Water body type, Water body source to help you classify.
#     Your answer should not contradict the given data elements. For example, if Water body type: is salt_water it can not be River_Stream due to the stream having salt content.
#     Your answer must be in this format, Answer: class name
# Example: Answer  River_
#     Answer should be one the of the seven options listed above.
#
#
#
#
# Processing complete. Final DataFrame saved.

# %% [markdown]
# # Additional iteration to classify Unknown values

# %%
globe_site_data = pd.read_csv(data_path + "globe_site_data_20250227.csv", dtype=str, low_memory=False)
globe_site_data.columns = globe_site_data.columns.str.strip()

globe_site_data[globe_site_data['harvard_class'] == 'Unknown']
# Out:
# Empty DataFrame
# Columns: [site_id, name, latitude, longitude, elevation, elevation_type, location_source, comments, activated_at, water_body_name, water_body_type, water_body_source, bank_to_bank_distance, bank_to_bank_distance_unit, area, area_unit, depth, depth_unit, water_sample_location, can_see_bottom, bank_material, bedrock_type, freshwater_habitat, salt_habitat, harvard_class]
# Index: []
#
# [0 rows x 25 columns]

# %%
# Second pass for rows previously labeled as 'Unknown'
unknown_indices = globe_site_data.index[globe_site_data['harvard_class'] == 'Unknown'].tolist()
second_pass_unknowns = []

# Column names
column_names = [col.replace('_', ' ').capitalize() + ':' for col in globe_site_data.columns if col != 'harvard_class']

# Optionally modify the prompt logic if needed
for count, idx in enumerate(unknown_indices, start=1):
    row = globe_site_data.loc[idx]

    # Create a more targeted prompt (optional)
    row_info = "\n".join(
        f"{col_name} {value}" for col_name, value in zip(column_names, row[globe_site_data.columns])
    )
    #row_info = f"The following record was previously unclassifiable. Try harder to classify it:\n{row_info}"

    # Re-run LLM classification
    llm_class_response, output_text = llm_labeler(row_info)

    # Track results
    if llm_class_response == 'Unknown':
        second_pass_unknowns.append(output_text)

    # Update DataFrame
    globe_site_data.at[idx, 'harvard_class'] = llm_class_response

    # Checkpoint save in data_path
    if count % 100 == 0:
        globe_site_data.to_csv(data_path + "globe_site_data_second_pass.csv", index=False)
        print(f"Second pass: processed {count} rows. Remaining 'Unknowns': {len(globe_site_data[globe_site_data['harvard_class'] == 'Unknown'])}\n")
        # Print the last 5 result from the unknown list
        new_five_exmaples = second_pass_unknowns[-5:]
        for example in new_five_exmaples:
            print(example)
        print("\n\n\n")

# Final save
globe_site_data.to_csv(data_path + "globe_site_data_20250227.csv", index=False)
print("Second pass complete. Final file saved.")
# Out:
# Second pass complete. Final file saved.
